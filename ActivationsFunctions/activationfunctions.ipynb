# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_circles

import matplotlib.pyplot as plt

x, y = make_circles(n_samples=1000, noise=0.1, random_state=1)

# %%
plt.figure(figsize=(10, 10))
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.RdYlBu)
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %% [markdown]
# Without using any activation functions:-

# %%
model = Sequential()

model.add(Dense(128, input_shape=(2,)))
model.add(Dropout(0.3))

model.add(Dense(64 ))
model.add(Dropout(0.4))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
callback1 = callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_46608/3347852453.py in <cell line: 0>()
# ----> 1 callback1 = callbacks.EarlyStopping(
#       2     monitor="val_loss",
#       3     min_delta=0,
#       4     patience=20,
#       5     verbose=1,
#
# NameError: name 'callbacks' is not defined

# %%
model.fit(x_train, y_train, epochs=2000, callbacks = callback1 )
# Out:
# Epoch 1/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4787 - loss: 0.2530
# Epoch 2/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5063 - loss: 0.2530
# Epoch 3/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4850 - loss: 0.2540
# Epoch 4/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4800 - loss: 0.2532
# Epoch 5/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4975 - loss: 0.2534
# Epoch 6/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4825 - loss: 0.2530
# Epoch 7/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4688 - loss: 0.2555
# Epoch 8/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4775 - loss: 0.2537
# Epoch 9/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5050 - loss: 0.2508
# Epoch 10/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5100 - loss: 0.2526
# Epoch 11/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4863 - loss: 0.2532
# ...

# %%
from mlxtend.plotting import plot_decision_regions
plt.title('without using activation function')

plot_decision_regions(x_train, y_train, clf=model, legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step
# <Axes: title={'center': 'without using activation function'}>

# %% [markdown]
# we can see that withut using activation function the neural network is not capturing the non linear datas and also problems like overfitting and vanishing gradient occur.

# %%
from tensorflow.keras import callbacks
callback = callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
model1  = Sequential()

model1.add(Dense(128, input_shape=(2,), activation='relu'))
model1.add(Dropout(0.3))
model1.add(Dense(64, activation='relu'))
model1.add(Dropout(0.4))
model1.add(Dense(1, activation='linear'))

model1.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
model1.fit(x_train,y_train,epochs=2000,callbacks=callback, validation_data=(x_test,y_test))
# Out:
# Epoch 1/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4462 - loss: 0.3367 - val_accuracy: 0.1950 - val_loss: 0.2949
# Epoch 2/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4313 - loss: 0.3011 - val_accuracy: 0.4150 - val_loss: 0.2880
# Epoch 3/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4100 - loss: 0.3006 - val_accuracy: 0.3200 - val_loss: 0.2790
# Epoch 4/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4650 - loss: 0.2853 - val_accuracy: 0.4300 - val_loss: 0.2747
# Epoch 5/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4475 - loss: 0.2814 - val_accuracy: 0.4600 - val_loss: 0.2639
# Epoch 6/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4150 - loss: 0.2882 - val_accuracy: 0.4850 - val_loss: 0.2570
# Epoch 7/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4888 - loss: 0.2650 - val_accuracy: 0.5300 - val_loss: 0.2474
# Epoch 8/2000
# ...

# %%
from mlxtend.plotting import plot_decision_regions
plt.title('using  activation function')
plot_decision_regions(x_train, y_train, clf=model1, legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step
# <Axes: title={'center': 'using  activation function'}>

# %% [markdown]
# we can see that using the activation function can help to improve the neural network performance.
