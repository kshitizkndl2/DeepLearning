# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_moons
x, y = make_moons(n_samples=200, noise=0.2, random_state=42)

# %%
x.shape
# Out:
# (200, 2)

# %%
y.shape
# Out:
# (200,)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential([

    Dense(128,activation = 'relu', input_shape=(2,)),
    Dropout(0.3),
    Dense(64,activation = 'relu'),
    Dropout(0.2),
    Dense(32,activation = 'relu'),
    Dropout(0.2),
    Dense(1,activation = 'linear')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'mse',metrics = ['mse'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y , random_state=42, test_size=0.2)

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
history = model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=1000,callbacks=callback)
# Out:
# Epoch 1/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3579 - mse: 0.3579 - val_loss: 0.2091 - val_mse: 0.2091
# Epoch 2/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2252 - mse: 0.2252 - val_loss: 0.1887 - val_mse: 0.1887
# Epoch 3/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2231 - mse: 0.2231 - val_loss: 0.1951 - val_mse: 0.1951
# Epoch 4/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.1682 - val_mse: 0.1682
# Epoch 5/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1936 - mse: 0.1936 - val_loss: 0.1493 - val_mse: 0.1493
# Epoch 6/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1745 - mse: 0.1745 - val_loss: 0.1465 - val_mse: 0.1465
# Epoch 7/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1677 - mse: 0.1677 - val_loss: 0.1347 - val_mse: 0.1347
# Epoch 8/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1644 - mse: 0.1644 - val_loss: 0.1231 - val_mse: 0.1231
# Epoch 9/1000
# ...

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plt.title('relu')
plot_decision_regions(x,y,model)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
# <Axes: title={'center': 'relu'}>

# %%
plt.figure()
plt.title('relu')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %%
model1 = Sequential([

    Dense(128,activation = 'leaky_relu', input_shape=(2,)),
    Dropout(0.3),
    Dense(64,activation = 'leaky_relu'),
    Dropout(0.2),
    Dense(32,activation = 'leaky_relu'),
    Dropout(0.2),
    Dense(1,activation = 'linear')
])

# %%
model1.compile(optimizer = 'adam', loss = 'mse',metrics = ['mse'])

# %%
callback1 = EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
history1 = model1.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=1000,callbacks=callback1)
# Out:
# Epoch 1/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.3806 - mse: 0.3806 - val_loss: 0.2486 - val_mse: 0.2486
# Epoch 2/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2459 - mse: 0.2459 - val_loss: 0.1914 - val_mse: 0.1914
# Epoch 3/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2220 - mse: 0.2220 - val_loss: 0.1820 - val_mse: 0.1820
# Epoch 4/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1985 - mse: 0.1985 - val_loss: 0.1606 - val_mse: 0.1606
# Epoch 5/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1746 - mse: 0.1746 - val_loss: 0.1426 - val_mse: 0.1426
# Epoch 6/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1674 - mse: 0.1674 - val_loss: 0.1352 - val_mse: 0.1352
# Epoch 7/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1548 - mse: 0.1548 - val_loss: 0.1315 - val_mse: 0.1315
# Epoch 8/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1536 - mse: 0.1536 - val_loss: 0.1248 - val_mse: 0.1248
# Epoch 9/1000
# ...

# %%
plt.title('leaky_relu')
plot_decision_regions(x,y,model1)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
# <Axes: title={'center': 'leaky_relu'}>

# %%
plt.figure()
plt.title('leaky_relu')
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.show()

# %%
model2 = Sequential([

    Dense(128,activation = 'elu', input_shape=(2,)),
    Dropout(0.3),
    Dense(64,activation = 'elu'),
    Dropout(0.2),
    Dense(32,activation = 'elu'),
    Dropout(0.2),
    Dense(1,activation = 'linear')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model2.compile(optimizer = 'adam', loss = 'mse',metrics = ['mse'])

# %%
callback2 = EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
history2 = model2.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=1000,callbacks=callback2)
# Out:
# Epoch 1/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3463 - mse: 0.3463 - val_loss: 0.3409 - val_mse: 0.3409
# Epoch 2/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2969 - mse: 0.2969 - val_loss: 0.1853 - val_mse: 0.1853
# Epoch 3/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2216 - mse: 0.2216 - val_loss: 0.1352 - val_mse: 0.1352
# Epoch 4/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1942 - mse: 0.1942 - val_loss: 0.1211 - val_mse: 0.1211
# Epoch 5/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1643 - mse: 0.1643 - val_loss: 0.1043 - val_mse: 0.1043
# Epoch 6/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1468 - mse: 0.1468 - val_loss: 0.1077 - val_mse: 0.1077
# Epoch 7/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1529 - mse: 0.1529 - val_loss: 0.1032 - val_mse: 0.1032
# Epoch 8/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1573 - mse: 0.1573 - val_loss: 0.1065 - val_mse: 0.1065
# Epoch 9/1000
# ...

# %%
plt.title('elu')
plot_decision_regions(x,y,model2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
# <Axes: title={'center': 'elu'}>

# %%
plt.figure()
plt.title('elu')
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.show()

# %%
model3 = Sequential([

    Dense(128,activation = 'selu', input_shape=(2,)),
    Dropout(0.3),
    Dense(64,activation = 'selu'),
    Dropout(0.2),
    Dense(32,activation = 'selu'),
    Dropout(0.2),
    Dense(1,activation = 'linear')
])

# %%
model3.compile(optimizer = 'adam', loss = 'mse',metrics = ['mse'])

# %%
callback3 = EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
history3 = model3.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=1000,callbacks=callback3)
# Out:
# Epoch 1/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.4379 - mse: 0.4379 - val_loss: 0.1789 - val_mse: 0.1789
# Epoch 2/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3817 - mse: 0.3817 - val_loss: 0.1443 - val_mse: 0.1443
# Epoch 3/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3137 - mse: 0.3137 - val_loss: 0.1423 - val_mse: 0.1423
# Epoch 4/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 0.1167 - val_mse: 0.1167
# Epoch 5/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 0.1197 - val_mse: 0.1197
# Epoch 6/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2299 - mse: 0.2299 - val_loss: 0.1160 - val_mse: 0.1160
# Epoch 7/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1947 - mse: 0.1947 - val_loss: 0.1124 - val_mse: 0.1124
# Epoch 8/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2112 - mse: 0.2112 - val_loss: 0.1094 - val_mse: 0.1094
# Epoch 9/1000
# ...

# %%
plt.title('selu')
plot_decision_regions(x,y,model3)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
# <Axes: title={'center': 'selu'}>

# %%
plt.figure()
plt.title('selu')
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.show()
